# %% [markdown]
# ## Q1. Explain the different types of data (qualitative and quantitative) and provide examples of each. Discuss nominal, ordinal, interval, and ratio scales?
#
# ANS. In statistics and data analysis, data can be broadly classified into two main types: qualitative and quantitative. These types are further divided into scales of measurement: nominal, ordinal, interval, and ratio. Understanding these helps in choosing the right statistical methods for analysis.
#
# 1. Qualitative Data (Categorical Data)
#
# Qualitative data describes qualities or characteristics. It cannot be measured numerically but can be categorized based on traits and labels.
#
# 🔹 Types of Qualitative Data:
#
# Nominal Scale:
#
# Ordinal Scale:
#
# 2. Quantitative Data (Numerical Data)
#
# Quantitative data is numerical and can be measured and compared. It represents quantities or amounts.
#
# 🔹 Types of Quantitative Data:
#
# Interval Scale:
#
# Ratio Scale:
#
#
# ## Q2. What are the measures of central tendency, and when should you use each? Discuss the mean, median,and mode with examples and situations where each is appropriate?
#
# ANS. Measures of central tendency are statistical tools used to identify the center or typical value in a dataset. The three main measures are:
#
# Mean (average)
#
# Median (middle value)
#
# Mode (most frequent value)
#
# 1. Mean (Arithmetic Average)
#
# Definition:
# The mean is the sum of all values divided by the number of values.
#
# Formula:
#
# \text{Mean} = \frac{\sum x}{n}
#
# 2. Median (Middle Value)
#
# Definition:
# The median is the middle value when the data is arranged in order. If there’s an even number of observations, take the average of the two middle values.
#
# 3. Mode (Most Frequent Value)
#
# Definition:
# The mode is the value that appears most frequently in the dataset.
#
#
# ## Q3. Explain the concept of dispersion. How do variance and standard deviation measure the spread of data?
#
# ANS. Dispersion refers to the extent to which data values vary or spread out from a central value (like the mean). It tells us how consistent or variable the data is.
#
# ## Why Dispersion Matters ##
#
# Two datasets can have the same mean but very different spreads.
#
# Measures of central tendency (like the mean) don’t show variability—dispersion completes the picture.
#
# Helps assess risk, reliability, and consistency.
#
# ## Common Measures of Dispersion
#
# - Range
#
# - Interquartile Range (IQR)
#
# - Variance
#
# - Standard Deviation
#
#
# 1️⃣ Variance (σ² or s²)
#
# Definition:
# Variance measures the average of the squared differences from the mean. It gives an overall sense of how much each value in a dataset deviates from the mean, on average.
#
# Formula (for population):
#
# \sigma^2 = \frac{\sum (x_i - \mu)^2}{N}
#
# s^2 = \frac{\sum (x_i - \bar{x})^2}{n - 1}
#
#
# 2️⃣ Standard Deviation (σ or s)
#
# Definition:
# Standard deviation is the square root of the variance. It is in the same unit as the original data, making it easier to interpret.
#
# Formula:
#
# \sigma = \sqrt{\sigma^2}
# \quad \text{or} \quad
# s = \sqrt{s^2}
#
# ## Q4. What is a box plot, and what can it tell you about the distribution of data?
#
# ANS. A box plot is a graphical representation of the distribution of a dataset based on a five-number summary:
#
# 1. Minimum
#
#
# 2. First Quartile (Q1)
#
#
# 3. Median (Q2)
#
#
# 4. Third Quartile (Q3)
#
#
# 5. Maximum
#
#  Structure of a Box Plot
#
# |——————|■■■■■■■■■■|——————|
# min     Q1    Q2    Q3     max
#
# Box: Represents the interquartile range (IQR), which is Q3 − Q1 (the middle 50% of the data).
#
# Line inside box: The median (Q2).
#
# Whiskers: Lines extending from Q1 to the minimum and from Q3 to the maximum (excluding outliers).
#
# Dots or asterisks outside whiskers: Represent outliers, if any.
#
# ## Q5. Discuss the role of random sampling in making inferences about populations.
#
# ANS.
#  ## Role of Random Sampling in Making Inferences About Populations ##
#
# Random sampling is a foundational concept in statistics that allows us to make reliable inferences (educated conclusions) about a larger population based on data from a smaller group.
#
# What Is Random Sampling?
#
# Random sampling is a method where every individual in a population has an equal chance of being selected for the sample. It eliminates bias and ensures the sample represents the diversity of the population.
#
# Why Is Random Sampling Important in Inference?
#
# Making inferences means using sample data to:
#
# Estimate population parameters (e.g., mean income)
#
# Test hypotheses (e.g., is a new medicine effective?)
#
# Make predictions
#
#
# ## Q6. Explain the concept of skewness and its types. How does skewness affect the interpretation of data?
#
# ANS. Skewness measures the asymmetry of a data distribution around its mean. In a perfectly symmetrical distribution, like the normal (bell curve), the mean, median, and mode are equal, and skewness = 0.
#
# But in real-world data, distributions are often skewed—they have a longer tail on one side.
#
#  Types of Skewness
#
# 1️⃣ Positive Skewness (Right Skewed)
#
# Tail on the right side (higher values stretch out)
#
# Mean > Median > Mode
#
# A few high values pull the mean upward
#
# 2️⃣ Negative Skewness (Left Skewed)
#
# Tail on the left side (lower values stretch out)
#
# Mean < Median < Mode
#
# A few very low values pull the mean downward
#
#
# 3️⃣ Zero Skewness (Symmetrical Distribution)
#
# Mean = Median = Mode
#
# The data is evenly distributed
#
# Shape is normal bell curve
#
#
# ## Q7. What is the interquartile range (IQR), and how is it used to detect outliers?
#
# ANS. The Interquartile Range (IQR) is a measure of statistical dispersion that describes the middle 50% of a dataset. It is the difference between the third quartile (Q3) and the first quartile (Q1):
#
# Purpose of IQR
#
# Measures spread of the middle half of the data
#
# Resistant to outliers (unlike range or standard deviation)
#
# Commonly used in box plots
#
# Helps in detecting outliers
#
# ## Q8. Discuss the conditions under which the binomial distribution is used?
#
# ANS. The binomial distribution is a discrete probability distribution used when an experiment or process meets specific conditions and involves a fixed number of independent trials, each resulting in a success or failure.
#
# ✅ Conditions for Using the Binomial Distribution
#
# To model a situation using the binomial distribution, all of the following conditions must be met:
#
#
# 1️⃣ Fixed Number of Trials (n)
#
# 2️⃣ Only Two Possible Outcomes per Trial
#
# 3️⃣ Constant Probability of Success (p)
#
# 4️⃣ Independent Trials
#
#
# ## Q9. Explain the properties of the normal distribution and the empirical rule (68-95-99.7 rule)?
#
# ANS. The normal distribution is one of the most important probability distributions in statistics. It’s also known as the Gaussian distribution or bell curve due to its characteristic shape.
#
# 🔵 Properties of the Normal Distribution
#
# 1. Symmetrical:
#
# The distribution is perfectly symmetrical about the mean.
#
# This means the mean = median = mode.
#
# 2. Bell-shaped Curve:
#
# The graph forms a bell shape, with most data clustered around the center.
#
#
#
# 3. Unimodal:
#
# There is only one peak, at the mean.
#
#
#
# 4. Asymptotic:
#
# The tails extend infinitely in both directions but never touch the horizontal axis.
#
#
#
# 5. Defined by Mean (μ) and Standard Deviation (σ):
#
# The location of the curve depends on the mean.
#
# 6. Total Area Under the Curve = 1:
#
# This means the probability of all outcomes sums to 100%.
#
#
#
#
# ## Q10. Provide a real-life example of a Poisson process and calculate the probability for a specific event?
#
# ANS.  Real-Life Example of a Poisson Process
#
# The Poisson process models the probability of a certain number of events occurring in a fixed interval of time or space when the events happen independently and at a constant average rate.
#
#
# Example:
# A customer support center receives an average of 3 calls every 10 minutes.
# We want to calculate the probability of receiving exactly 5 calls in a 10-minute interval.
#
#
# Poisson Distribution Formula:
#
# P(X = k) = \frac{e^{-\lambda} \lambda^k}{k!}
#
# Where:
#
#  = number of events (calls)
#
#  = average number of events in the interval (mean)
#
#  = number of events we want the probability for
#
#
#  🧮 Given:
#
# Average rate (λ) = 3 calls per 10 minutes
#
# Number of calls we want to find the probability for =
#
#
# 🧾 Calculate:
#
# P(X = 5) = \frac{e^{-3} \cdot 3^5}{5!}
# = \frac{2.71828^{-3} \cdot 243}{120}
# ≈ \frac{0.0498 \cdot 243}{120}
# ≈ \frac{12.1}{120}
# ≈ 0.1008
#
#
#
# ✅ Answer:
#
# The probability of receiving exactly 5 calls in 10 minutes is approximately 0.1008, or 10.08%.
#
#
# ## Q11. Explain what a random variable is and differentiate between discrete and continuous random variables.
#
# ANS. A random variable is a numerical outcome of a random process or experiment. It assigns a real number to each possible outcome in a sample space.
#
# It’s called “random” because the value it takes depends on chance.
#
# Denoted by symbols like , , or
#
#
# Types of Random Variables
#
# Random variables are classified into two main types:
#
# 1️⃣ Discrete Random Variable
#
# Takes on a finite or countable number of distinct values
#
# Often the result of counting (e.g., number of students, cars, or calls)
#
# Can be represented using a probability mass function (PMF)
#
# 2️⃣ Continuous Random Variable
#
# Takes on an infinite number of values within a given range
#
# Often the result of measuring (e.g., time, height, weight)
#
# Represented using a probability density function (PDF)
#
#
# ## Q12. Provide an example dataset, calculate both covariance and correlation, and interpret the results.
#
# ANS.  Let's walk through an example dataset, calculate covariance and correlation, and interpret their meanings
#
#
# 📊 Example Dataset
#
# Let’s say we have data on study hours and exam scores of 5 students:
#
# Student	Study Hours (X)	Exam Score (Y)
#
# A	             2	         65
#
# B	             4	         70
#
# C	             6	         75
#
# D	             8	         85
#
# E	             10          95
#
#
# 1️⃣ Step 1: Calculate the Means
#
# \bar{X} = \frac{2 + 4 + 6 + 8 + 10}{5} = \frac{30}{5} = 6
#
# \bar{Y} = \frac{65 + 70 + 75 + 85 + 95}{5} = \frac{390}{5} = 78 ]
#
#
# ---
#
# 2️⃣ Step 2: Compute Covariance
#
# Covariance formula:
#
# \text{Cov}(X, Y) = \frac{\sum (X_i - \bar{X})(Y_i - \bar{Y})}{n}
#
# X	Y
#
# 2	65	-4	-13	52
# 4	70	-2	-8	16
# 6	75	0	-3	0
# 8	85	2	7	14
# 10	95	4	17	68
#
# \text{Cov}(X, Y) = \frac{52 + 16 + 0 + 14 + 68}{5} = \frac{150}{5} = 30
#
# ✅ Covariance = 30
#
#
# 3️⃣ Step 3: Compute Correlation
#
# Correlation formula (Pearson r):
#
# r = \frac{\text{Cov}(X, Y)}{\sigma_X \sigma_Y}
#
# We need the standard deviations  and :
#
# For :
#
# \sigma_X = \sqrt{\frac{\sum (X_i - \bar{X})^2}{n}} = \sqrt{\frac{16 + 4 + 0 + 4 + 16}{5}} = \sqrt{\frac{40}{5}} = \sqrt{8} ≈ 2.83
#
# For :
#
# \sigma_Y = \sqrt{\frac{\sum (Y_i - \bar{Y})^2}{n}} = \sqrt{\frac{169 + 64 + 9 + 49 + 289}{5}} = \sqrt{\frac{580}{5}} = \sqrt{116} ≈ 10.77
#
# r = \frac{30}{2.83 \times 10.77} ≈ \frac{30}{30.47} ≈ 0.984
#
# ✅ Correlation (r) ≈ 0.984
